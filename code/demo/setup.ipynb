# %%
mkdir -p /home/tiennd3886/BTL-MMDS/demo

# %%
# !hdfs dfs -get /user/tiennd3886/models/sparkml/run_20260525_151654/xgb_hw/native_b /home/tiennd3886/BTL-MMDS/demo/kshape

# %%
# !tar -czvf /home/tiennd3886/BTL-MMDS/demo/kshape.tar.gz /home/tiennd3886/BTL-MMDS/demo/kshape
# Out:
# tar: Removing leading `/' from member names
# /home/tiennd3886/BTL-MMDS/demo/kshape/
# /home/tiennd3886/BTL-MMDS/demo/kshape/.ipynb_checkpoints/
# /home/tiennd3886/BTL-MMDS/demo/kshape/.ipynb_checkpoints/pipeline_metadata-checkpoint.json
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/model/
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/model/part-00000
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/model/_SUCCESS
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/metadata/
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/metadata/part-00000
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_xgb_model/metadata/_SUCCESS
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_ridge_meta_model/
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_ridge_meta_model/metadata/
# /home/tiennd3886/BTL-MMDS/demo/kshape/spark_ridge_meta_model/metadata/part-00000
# ...

# %%
# !hdfs dfs -get /user/vietanhdata/models/taxi_demand_gbt_model /home/tiennd3886/BTL-MMDS/demo/gbt

# %%
# !tar -czvf /home/tiennd3886/BTL-MMDS/demo/gbt.tar.gz /home/tiennd3886/BTL-MMDS/demo/gbt
# Out:
# tar: Removing leading `/' from member names
# /home/tiennd3886/BTL-MMDS/demo/gbt/
# /home/tiennd3886/BTL-MMDS/demo/gbt/treesMetadata/
# /home/tiennd3886/BTL-MMDS/demo/gbt/treesMetadata/part-00000-51e7b498-a53a-4c1a-a32e-8dc8838b2679-c000.snappy.parquet
# /home/tiennd3886/BTL-MMDS/demo/gbt/treesMetadata/_SUCCESS
# /home/tiennd3886/BTL-MMDS/demo/gbt/metadata/
# /home/tiennd3886/BTL-MMDS/demo/gbt/metadata/part-00000
# /home/tiennd3886/BTL-MMDS/demo/gbt/metadata/_SUCCESS
# /home/tiennd3886/BTL-MMDS/demo/gbt/data/
# /home/tiennd3886/BTL-MMDS/demo/gbt/data/part-00000-97e67958-4f52-4191-9cf1-40ac0cee34fe-c000.snappy.parquet
# /home/tiennd3886/BTL-MMDS/demo/gbt/data/_SUCCESS
