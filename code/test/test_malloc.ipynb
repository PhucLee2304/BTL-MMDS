# %%
import pandas as pd
import os
import sys
import gc

# %%
if __name__ == "__main__":
    trigger_malloc_error_with_data()
# Out:
# --- Starting Realistic Memory Allocation Test ---
# Data path in use: c:\Users\Admin\BTL-MMDS\data\raw
# Iteration 1, loaded yellow_tripdata_2025-01.parquet: 3,475,226 rows (~0.62 GB)
# Iteration 1, loaded yellow_tripdata_2025-02.parquet: 7,052,769 rows (~1.26 GB)
# Iteration 1, loaded yellow_tripdata_2025-03.parquet: 11,198,026 rows (~1.99 GB)
# Iteration 1, loaded yellow_tripdata_2025-04.parquet: 15,168,579 rows (~2.70 GB)
# Iteration 1, loaded yellow_tripdata_2025-05.parquet: 19,760,424 rows (~3.51 GB)
# Iteration 1, loaded yellow_tripdata_2025-06.parquet: 24,083,384 rows (~4.27 GB)
# Iteration 2, loaded yellow_tripdata_2025-01.parquet: 27,558,610 rows (~4.89 GB)
# Iteration 2, loaded yellow_tripdata_2025-02.parquet: 31,136,153 rows (~5.53 GB)
# Iteration 2, loaded yellow_tripdata_2025-03.parquet: 35,281,410 rows (~6.26 GB)
# Iteration 2, loaded yellow_tripdata_2025-04.parquet: 39,251,963 rows (~6.97 GB)
# ...
