# %%
# Install libraries on master
# !pip install -U numpy pandas scikit-learn tensorflow xgboost joblib spark-tensorflow-distributor tensorflow_io

# %%
# Install libraries on workers
# !ssh hadoop-worker-1 "/home/tiennd3886/BTL-MMDS/env/bin/python3 -m pip install -U numpy pandas scikit-learn tensorflow xgboost joblib spark-tensorflow-distributor tensorflow_io"
# !ssh hadoop-worker-2 "/home/tiennd3886/BTL-MMDS/env/bin/python3 -m pip install -U numpy pandas scikit-learn tensorflow xgboost joblib spark-tensorflow-distributor tensorflow_io"

# %%
# !hdfs dfs -rm -r /user/kshape/model/models
# !hdfs dfs -rm -r /user/kshape/model/predictions
# !hdfs dfs -rm -r /user/kshape/model/demo
# !hdfs dfs -rm -r /user/kshape/model/metrics
# Out:
# Deleted /user/kshape/model/models
# Deleted /user/kshape/model/predictions
# rm: `/user/kshape/model/demo': No such file or directory
# rm: `/user/kshape/model/metrics': No such file or directory

# %%
# !ssh hadoop-worker-1 "ls -lh /tmp/cnn_model_export/ 2>/dev/null || echo 'NOT FOUND'"
# !ssh hadoop-worker-2 "ls -lh /tmp/cnn_model_export/ 2>/dev/null || echo 'NOT FOUND'"
# !ssh hadoop-worker-3 "ls -lh /tmp/cnn_model_export/ 2>/dev/null || echo 'NOT FOUND'"

# %%
# !ssh hadoop-worker-1 "ls -lah /tmp"
# !ssh hadoop-worker-2 "ls -lah /tmp"
# !ssh hadoop-worker-3 "ls -lah /tmp"
